# %% [markdown]
# # Categorical scatter plots

# %% [markdown]
# The aim of this tutorial is to reproduce the following figure. You can imagine this figure as measuring A and B from a set of samples numbered (1,2,3,...).

# %%
from IPython.display import Image
Image('todo')

# %% [markdown]
# Of course, the first thing we need is the data. Usually this data will come from your experiments or your computations, but here we are going to generate it. It's always good to be able to generate some fake data to see if our algorithms will work.
#
# The package [scikit-learn](http://scikit-learn.org/stable/) provides lots of tools for data mining, data analysis and visualization. We will introduce it in a future lecture in this course. Here we will only use it to generate our data. The `datasets` module has several functions to generate different types of data. We will use [make_blobs](http://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_blobs.html#sklearn.datasets.make_blobs).

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 6.0)
from sklearn.datasets.samples_generator import make_blobs

# %%
X, y = blobs = datasets.make_blobs(n_samples=500, centers=5, cluster_std=1.5, random_state=8)

# %%
plt.scatter(X[:,0], X[:,1])

# %%
import matplotlib.cm as cm
colors = cm.rainbow(np.linspace(0, 1, len(np.unique(y))))
for yi, c in zip(np.unique(y), colors):
    plt.scatter(X[y==yi,0], X[y==yi,1], color=c, alpha=0.6, label=yi)
plt.legend(loc='best')

# %%
import prettyplotlib as pplt

# %%
for yi in np.unique(y):
    pplt.scatter(X[y==yi,0], X[y==yi,1], label=yi)
pplt.legend()

# %%
kb=1.38064e-23
h=6.626069e-34
R=1.987204e-3
T=295.
dG=20.7
kb*T/h*np.exp(-dG/R/T)
print(-R*T*np.log(0.16/60*h/kb/T), -R*T*np.log((0.16+0.03)/60*h/kb/T), -R*T*np.log((0.16-0.03)/60*h/kb/T))
# Out:
# 20.7370549774 20.6363120296 20.8587784014

# %%
(np.exp(-dG/R/T)-np.exp(-35/R/T))/((np.exp(-14/R/T)-np.exp(-35/R/T)))
# Out:
# 1.0874876914945089e-05

# %%
-R*T*(np.logaddexp(-dG/R/T, -35/R/T)-np.logaddexp(-14/R/T, -35/R/T))
# Out:
# 6.6999999999850646

# %%
-R*T*(np.logaddexp(-dG/R/T, -33/R/T)-np.logaddexp(-16/R/T, -33/R/T))
# Out:
# 4.6999999995474306

# %%
-R*T*(np.logaddexp(-dG/R/T, -37/R/T)-np.logaddexp(-12/R/T, -37/R/T))
# Out:
# 8.6999999999995072
